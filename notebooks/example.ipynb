# %%
# have modules be re-loaded when cells are executed
# this is helpful for us since then we can edit gp.py
# without needing to manually restart the kernel
# %load_ext autoreload
# %autoreload 2

# %%
import gp

# %%
import pickle # for dumping models to a file
import matplotlib.pyplot as plt # for plotting

# %%
m = gp.GaussianProcessModel(
    h = 'real', # use real IMD from ROOT file in this directory
    kernel = gp.kernels.RBF(length_scale=0.016)*gp.kernels.DotProduct(sigma_0 = 25000), # provide kernel to use
    blind_range = (0.045, 0.055),
    modify_histogram = gp._hist.manipulation.rebin_and_limit(10, 0.033, 0.179)
)
m.model
# Out:
# GaussianProcessRegressor(alpha=array([  880.,  1117.,  1419.,  1845.,  2473.,  2992.,  3720.,  4470.,
#         5261.,  6174.,  7141.,  8043.,  9127., 10363., 11579., 12721.,
#        13875., 15198., 16183., 17188., 18445., 20118., 21024., 22297.,
#        38903., 39071., 39616., 40037., 40229., 40838., 40918., 40991.,
#        41851., 41144., 41494., 41924., 42158., 42083., 42036., 42433.,
#        42350., 42212., 42186., 42103., 42155., 42152., 4221...
#         1299.,  1346.,  1209.,  1223.,  1135.,  1160.,  1076.,  1102.,
#         1036.,  1088.,  1087.,  1062.,  1002.,  1037.,   941.,   925.,
#          852.,   877.,   895.,   819.,   802.,   777.,   797.,   797.,
#          681.,   756.,   710.,   670.,   719.,   680.,   598.,   646.,
#          607.,   618.,   531.,   573.,   608.,   581.,   547.,   532.,
#          511.,   521.,   483.,   483.,   489.,   486.,   488.,   469.,
#          475.,   385.,   411.,   384.,   405.,   378.,   395.,   406.]),
# ...

# %%
m.kernel
# Out:
# RBF(length_scale=0.0159) * DotProduct(sigma_0=2.16e+04)

# %%
fig, ax = m.plot_comparison()
plt.show()

# %%
m.plot_pull_histogram()
gp.label()
plt.show()
