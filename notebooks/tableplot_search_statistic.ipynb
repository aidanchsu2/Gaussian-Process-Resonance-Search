# %%
import sys
import pickle
import uproot
import matplotlib.pyplot as plt 
import pandas as pd
import math
file_1 = pd.read_excel("search_test_rbn2.xlsx")
x1 = file_1["Mass"]
y1 = file_1["Statistic"]
plt.plot(x1,y1)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 2")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 7
#       5 import pandas as pd
#       6 import math
# ----> 7 file_1 = pd.read_excel("search_test_rbn2.xlsx")
#       8 x1 = file_1["Mass"]
#       9 y1 = file_1["Statistic"]
#
# File ~/Documents/gaus-proc/.venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
file_1.to_csv("search_sheet.csv")

# %%
y2 = file_1["p-value"]
plt.plot(x1,y2)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 2, log scale")
plt.yscale('log')

# %%
file_2 = pd.read_excel("search_test_rbn5.xlsx")
y3 = file_2["Statistic"]
y4 = file_2["p-value"]
plt.plot(x1,y3)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 5")

# %%
plt.plot(x1,y4)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 5, log scale")
plt.yscale('log')

# %%
file_3 = pd.read_excel("search_test_rbn40.xlsx")
y5 = file_3["Statistic"]
y6 = file_3["p-value"]
plt.plot(x1,y5)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40")

# %%
plt.plot(x1,y6)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, log scale")
plt.yscale('log')

# %%
file_4 = pd.read_excel("search_test_rbn10.xlsx")
x = file_4["Mass"]
y6 = file_4["Statistic"]
y7 = file_4["p-value"]
plt.plot(x,y6)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 10, WhiteKernel")
# Out:
# Text(0.5, 1.0, 'Rebin 10, WhiteKernel')

# %%
plt.plot(x,y7)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 10, WhiteKernel")
plt.yscale('log')

# %%
file_5 = pd.read_csv("search_test_rbn5.csv")
x = file_5["Mass"]
y7 = file_5["Statistic"]
y8 = file_5["p-value"]
plt.plot(x,y7)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 5, WhiteKernel")
# Out:
# Text(0.5, 1.0, 'Rebin 5, WhiteKernel')

# %%
plt.plot(x,y8)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 5, WhiteKernel")
plt.yscale('log')

# %%
file_6 = pd.read_csv("search_test_rbn40.csv")
x = file_6["Mass"]
y9 = file_6["Statistic"]
y10 = file_6["p-value"]
plt.plot(x,y9)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel")
# Out:
# Text(0.5, 1.0, 'Rebin 40, WhiteKernel')

# %%
plt.plot(x,y10)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel")
plt.yscale('log')

# %%
file_7 = pd.read_csv("search_test_rbn40_2sigma.csv")
x = file_7["Mass"]
y11 = file_7["Statistic"]
y12 = file_7["p-value"]
plt.plot(x,y11)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 2 sigma")
# Out:
# Text(0.5, 1.0, 'Rebin 40, WhiteKernel, 2 sigma')

# %%
plt.plot(x,y12)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 2 sigma")
plt.yscale('log')

# %%
file_8 = pd.read_csv("search_test_rbn5_2sigma.csv")
x = file_8["Mass"]
y13 = file_8["Statistic"]
y14 = file_8["p-value"]
plt.plot(x,y13)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 5, WhiteKernel, 2 sigma")
# Out:
# Text(0.5, 1.0, 'Rebin 5, WhiteKernel, 2 sigma')

# %%
plt.plot(x,y14)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 5, WhiteKernel, 2 sigma")
plt.yscale('log')
# Out:
# (0.035, 0.17)

# %%
file_9 = pd.read_csv("search_test_rbn5_2sigma_range2.csv")
x = file_9["Mass"]
y15 = file_9["Statistic"]
y16 = file_9["p-value"]
plt.plot(x,y15)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 5, WhiteKernel, 2 sigma, smaller range")
# Out:
# Text(0.5, 1.0, 'Rebin 5, WhiteKernel, 2 sigma, smaller range')

# %%
plt.plot(x,y16)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 5, WhiteKernel, 2 sigma, smaller range")
plt.yscale('log')

# %%
file_10 = pd.read_csv("search_test_rbn40_2sigma_range2.csv")
x = file_10["Mass"]
y17 = file_10["Statistic"]
y18 = file_10["p-value"]
plt.plot(x,y17)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 2 sigma, smaller range")
# Out:
# Text(0.5, 1.0, 'Rebin 40, WhiteKernel, 2 sigma, smaller range')

# %%
plt.plot(x,y18)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 2 sigma, smaller range")
plt.yscale('log')

# %%
file_11 = pd.read_csv("search_test_rbn40_range2.csv")
x = file_11["Mass"]
y19 = file_11["Statistic"]
y20 = file_11["p-value"]
plt.plot(x,y19)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, smaller range")
# Out:
# Text(0.5, 1.0, 'Rebin 40, WhiteKernel, smaller range')

# %%
plt.plot(x,y20)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, smaller range")
plt.yscale('log')

# %%
file_12 = pd.read_csv("search_test_rbn40_5000signal_100mev.csv")
x = file_12["Mass"]
y21 = file_12["Statistic"]
y22 = file_12["p-value"]
plt.plot(x,y21)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 5000 events at 100 MeV, smaller range")
# Out:
# Text(0.5, 1.0, 'Rebin 40, WhiteKernel, 5000 events at 100 MeV')

# %%
plt.plot(x,y22)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 5000 events at 100 MeV, smaller range")
plt.yscale('log')

# %%
file = pd.read_csv("search_test_rbn40_5000signal_120mev.csv")
x = file["Mass"]
y1 = file["Statistic"]
y2 = file["p-value"]
plt.plot(x,y1)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 5000 events at 120 MeV, smaller range")
# Out:
# Text(0.5, 1.0, 'Rebin 40, WhiteKernel, 5000 events at 120 MeV')

# %%
plt.plot(x,y2)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 5000 events at 120 MeV, smaller range")
plt.yscale('log')

# %%
file = pd.read_csv("search_test_rbn40_5000signal_100mev.csv")
x = file["Mass"]
y1 = file["Statistic"]
y2 = file["p-value"]
plt.plot(x,y1)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 5000 events at 100 MeV")
# Out:
# Text(0.5, 1.0, 'Rebin 40, WhiteKernel, 5000 events at 100 MeV')

# %%
plt.plot(x,y2)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 5000 events at 100 MeV")
plt.yscale('log')

# %%
file = pd.read_csv("search_test_rbn40.csv")
x = file["Mass"]
y1 = file["Statistic"]
y2 = file["p-value"]
plt.plot(x,y1)
plt.ylabel("Statistic")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel, 5000 events at 100 MeV")
# Out:
# Text(0.5, 1.0, 'Rebin 40, WhiteKernel, 5000 events at 100 MeV')

# %%
plt.plot(x,y2)
plt.ylabel("p-value")
plt.xlabel("Mass")
plt.title("Rebin 40, WhiteKernel")
plt.yscale('log')
