# %%
import sys
import pickle
import uproot
import matplotlib.pyplot as plt 
import pandas as pd
import math
file_1 = pd.read_excel("ul_test_fixed_no_rebin.xlsx")
x1 = file_1["Mass"]
y1 = file_1["Upper Limit"]
plt.plot(x1,y1)
plt.ylabel("Upper Limit")
plt.xlabel("Mass")
plt.title("No Rebin")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 7
#       5 import pandas as pd
#       6 import math
# ----> 7 file_1 = pd.read_excel("ul_test_fixed_no_rebin.xlsx")
#       8 x1 = file_1["Mass"]
#       9 y1 = file_1["Upper Limit"]
#
# File ~/Documents/gaus-proc/.venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
file_2 = pd.read_csv("ul_test_rbn5_smeared.csv")
x = file_2["Mass"]
y2 = file_2["Upper Limit"]
plt.plot(x,y2)
plt.ylabel("Upper Limit")
plt.xlabel("Mass")
plt.title("Rebin 5, WhiteKernel")

ax = plt.gca()
ax.set_xlim([.033, .153])
#ax.set_ylim([0, 400000])
plt.yscale("log")

# %%
file_2 = pd.read_csv("ul_test_rbn2_smeared.csv")
x = file_2["Mass"]
y2 = file_2["Upper Limit"]
plt.plot(x,y2)
plt.ylabel("Upper Limit")
plt.xlabel("Mass")
plt.title("Rebin 2, WhiteKernel")

ax = plt.gca()
ax.set_xlim([.033, .153])
#ax.set_ylim([0, 400000])
plt.yscale("log")

# %%
file_2 = pd.read_csv("ul_2015_rbn2.csv")
x = file_2["Mass"]
y2 = file_2["Upper Limit"]
plt.plot(x,y2)
plt.ylabel("Upper Limit")
plt.xlabel("Mass")
plt.title("Rebin 2, WhiteKernel 2015 100%")

ax = plt.gca()
ax.set_xlim([.015, .120])
#ax.set_ylim([0, 400000])
plt.yscale("log")

# %%
file_2 = pd.read_csv("ul_2015_rbn2_fixed.csv")
x = file_2["Mass"]
y2 = file_2["Upper Limit"]
plt.plot(x,y2)
plt.ylabel("Upper Limit")
plt.xlabel("Mass")
plt.title("Rebin 2, WhiteKernel 2015 100%")

ax = plt.gca()
ax.set_xlim([.015, .120])
#ax.set_ylim([0, 400000])
plt.yscale("log")

# %%
file_2 = pd.read_csv("ul_2015_rbn1_fixed.csv")
x = file_2["Mass"]
y2 = file_2["Upper Limit"]
plt.plot(x,y2)
plt.ylabel("Upper Limit")
plt.xlabel("Mass")
plt.title("No Rebin, WhiteKernel 2015 100%")

ax = plt.gca()
ax.set_xlim([.015, .120])
#ax.set_ylim([0, 400000])
plt.yscale("log")

# %%
file_2 = pd.read_csv("ul_2015_rbn1_fixed.csv")
file_3 = pd.read_excel("ul_2016_rbn2_fixed.xlsx")
x = file_2["Mass"]
y2 = file_2["Upper Limit"]
plt.plot(x,y2,label="2015 100%, no rebin")
plt.ylabel("Upper Limit")
plt.xlabel("Mass")
plt.title("Upper Limit on Signal Yield, WhiteKernel")
x2 = file_3["Mass"]
y3 = file_3["Upper Limit"]
plt.plot(x2,y3,label="2016 10%, rebin 2")
ax = plt.gca()
ax.set_xlim([.015, .179])
#ax.set_ylim([0, 400000])
plt.yscale("log")
ax.legend()
